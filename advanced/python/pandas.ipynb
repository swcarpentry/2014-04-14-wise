# %% [markdown]
# # Pandas for data wrangling
#
# _Prepared by: Cindee Madison

# %% [markdown]
# ## 1. Introduction
#
#
# We will use **pandas** to easily read, modify, and write back out a comma-separated-values (csv) file, and Excel Files.
#
#
# Link to master notebook with solutions [master](http://swcarpentry.github.io/2014-04-14-wise/advanced/python/pandas-master.ipynb)

# %% [markdown]
# ###Pandas
#
# There are several packages for dealing with structured data in a more intelligent way (e.g., see [matplotlib.mlab](http://matplotlib.org/api/mlab_api.html) and [recarrays](http://docs.scipy.org/doc/numpy/reference/generated/numpy.recarray.html).  However, in recent years, [Pandas]( http://pandas.pydata.org/) has risen above the rest in its usability and flexibility.
#
# Pandas is one of the most powerful tools for doing data analysis in python.  It provides a way of representing, reading/writing, manipulating, analyzing, and plotting your data (among others). It has a fairly steep learning curve, but we assure you it will be worth it.
#
# The main data structure in Pandas is known as the "DataFrame" (which is quite similar to a Dataframe in R, if you're into that kind of thing...).  It let's you conveniently and clearly store, manipulate, plot, store, filter, etc, all kinds of data.
#
# While we can create dataframes manually, here we will use Pandas I/O functionality, which can easily read from csv files (and from many others as well, such as JSON, HTML, mySQL, or HDF)
#
# >Note - Pandas can do *a lot*, and it's a very complicated package to understand in full.  For this tutorial, we will stick with reading in data, looking at it, and writing it     back to a file.  If you want to do more with pandas, check out the [extensive documentation](http://pandas.pydata.org/pandas-docs/stable/) online (though be prepared for a relatively steep learning curve)

# %% [markdown]
# ### Files you will need if not working in the repo
#
# [small_sample.csv](http://swcarpentry.github.io/2014-04-14-wise/advanced/python/small_sample.csv)
#
# [sightings.xls](http://swcarpentry.github.io/2014-04-14-wise/advanced/python/sightings.xls)

# %%
try:
    # %matplotlib inline
except:
    # %pylab inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
## look at the csv file
# !cat small_sample.csv
# Out:
# Date,Time,Animal,Count
# 2011-04-22,16:20,Owl,14
# 2011-04-22,10:08,Fox,4
# 2011-04-23,06:29,Muskox,31
# 2011-04-23,21:11,Owl,20
# 2011-04-23,07:41,Muskox,20

# %%
# First we will read in the data from the CSV file.
# Pandas has inherent fanciness that displays data in nice tabular format.
csv_file = 'small_sample.csv'
df = pd.read_csv(csv_file)
df
# Out:
#          Date   Time  Animal  Count
# 0  2011-04-22  16:20     Owl     14
# 1  2011-04-22  10:08     Fox      4
# 2  2011-04-23  06:29  Muskox     31
# 3  2011-04-23  21:11     Owl     20
# 4  2011-04-23  07:41  Muskox     20
#
# [5 rows x 4 columns]

# %%
pd.read_csv?

# %%
## DataFrames can hold multiple different datatypes
print type(df.Date.values[0])  # dates are currently strings
print df.dtypes
## Count is a int64
# Out:
# <type 'str'>
# Date      object
# Time      object
# Animal    object
# Count      int64
# dtype: object

# %% [markdown]
# ##Columns
#
# Data frames have columns, which we can use to access the data in a column
#
# * If the column name is a simple word we can access via an attribute reference
#
#     ```
#     df.Animal
#     ```
#
# * Columns can also be accessed much like a dictionary
#
#     ```
#     df['Animal']
#     ```

# %%
# a dataframe has colums. We use the columns names to access each column
df.columns
# Out:
# Index([u'Date', u'Time', u'Animal', u'Count'], dtype='object')

# %%
## we can access the data in each column in two ways
## This works if the column names are simple single words, if a column header has spaces
## or special character (like % or &) then you need to specify the exact string
#df['Animal']
df.Animal
# Out:
# 0       Owl
# 1       Fox
# 2    Muskox
# 3       Owl
# 4    Muskox
# Name: Animal, dtype: object

# %% [markdown]
# ### Exercise
#
# Access the animal column
#
# how can you find unique animals?
#
# hint set?

# %%
set([1,1,1,2,3,4,4,4])
# Out:
# {1, 2, 3, 4}

# %%
set(df.Animal)
# Out:
# {'Fox', 'Muskox', 'Owl'}

# %% [markdown]
# ##Series
#
# One column from a DataFrame is a Series
#
# http://pandas.pydata.org/pandas-docs/stable/dsintro.html
#
#
# * You can slice a Series like an array
# * You can slice a series like a dict
# * you can use vectorized operations on a series

# %%
df[['Count','Animal' ]][:2]
# Out:
#    Count Animal
# 0     14    Owl
# 1      4    Fox
#
# [2 rows x 2 columns]

# %%
counts = df.Count
type(counts)
# Out:
# pandas.core.series.Series

# %%
counts
# Out:
# 0    14
# 1     4
# 2    31
# 3    20
# 4    20
# Name: Count, dtype: int64

# %%
df
# Out:
#          Date   Time  Animal  Count
# 0  2011-04-22  16:20     Owl     14
# 1  2011-04-22  10:08     Fox      4
# 2  2011-04-23  06:29  Muskox     31
# 3  2011-04-23  21:11     Owl     20
# 4  2011-04-23  07:41  Muskox     20
#
# [5 rows x 4 columns]

# %%
print counts.index
##I can make the index a set of names
counts.index = df.Animal
print counts
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')
# Animal
# Owl       14
# Fox        4
# Muskox    31
# Owl       20
# Muskox    20
# Name: Count, dtype: int64

# %%
#I can index like an array
print 'array-like'
print counts[0]
#or like a dictionary
print 'dict-like'
print counts['Owl']
# Out:
# array-like
# 14
# dict-like
# Owl    14
# Owl    20
# Name: Count, dtype: int64

# %%
# Vectorized operation on values
counts * 2
# Out:
# Animal
# Owl       28
# Fox        8
# Muskox    62
# Owl       40
# Muskox    40
# Name: Count, dtype: int64

# %% [markdown]
# ### Exercise
#
# Create a series by grabbing the Animal column
#
# What happens if you use a vectorized operation on string values?

# %%
myser = df.Animal
myser * 2
# Out:
# 0          OwlOwl
# 1          FoxFox
# 2    MuskoxMuskox
# 3          OwlOwl
# 4    MuskoxMuskox
# Name: Animal, dtype: object

# %% [markdown]
# ##DataFrames are made up of Series
#
# * You can easily create a new dataframe from a subset of columns

# %%
# I can create a new dataframe form a subset of columns easily
small_df = df[['Animal', 'Count']]
print small_df
# Out:
#    Animal  Count
# 0     Owl     14
# 1     Fox      4
# 2  Muskox     31
# 3     Owl     20
# 4  Muskox     20
#
# [5 rows x 2 columns]

# %%
## Accessing rows is a little more difficult
## df[0] # This will raise an error
## Tho I can slice to get a few rows
df[:1]
# Out:
#          Date   Time Animal  Count
# 0  2011-04-22  16:20    Owl     14
#
# [1 rows x 4 columns]

# %% [markdown]
# ## To slice a row, you need to use .ix

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# counts     Series       Animal\nOwl       14\nFox<...>Name: Count, dtype: int64
# csv_file   str          small_sample.csv
# df         DataFrame             Date   Time  Ani<...>0\n\n[5 rows x 4 columns]
# myser      Series       0       Owl\n1       Fox\<...>me: Animal, dtype: object
# pd         module       <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# plt        module       <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# small_df   DataFrame       Animal  Count\n0     O<...>0\n\n[5 rows x 2 columns]

# %%
df.ix[2]

# %%
# Note that we can explicitly turn our values into an array
# by using the "values" attribute
type(df.values)

# %%
## If we explicity grab the values as a numpy array, we can easily index
## First row, all columns
df.values[2,:]

# %% [markdown]
# ### There are a large number of control parameters when reading a csv
# 1. sep : default is comma, but you can specify '\t' (tab) or if unsure, try sep=None
# 2. skiprows : sometimes you want to skip a couple rows, eg skiprows = 2
#
# To find all the options
# pd.read_csv?

# %% [markdown]
# ## You can use pandas to write a new files
# 1. we created small_df above, just holding Animal and Count. We can write this to a new file:
#
#     small_df.to_csv('small_sample.csv')

# %%
# write small_df to a file called small_sample.csv
# check that is exists using !ls
small_df.to_csv('small_sample.csv')
# !ls
# Out:
# Numpy-master.ipynb          pandas-master.ipynb
# Numpy.ipynb                 pandas.ipynb
# Untitled0.ipynb             py-intro
# classes-master.ipynb        scipy.ipynb
# classes.ipynb               sightings.xls
# matplotlib_instructor.ipynb small_sample.csv
# matplotlib_master.ipynb     small_sample.xls
# matplotlib_student.ipynb    testing

# %% [markdown]
# ###Exercise
#
# Can you write small_df to an excel file?
#
# small_df.to_excel?

# %%
#create an excel file
small_df.to_excel('small_sample.xls')
# !ls
# Out:
# Numpy-master.ipynb          pandas-master.ipynb
# Numpy.ipynb                 pandas.ipynb
# Untitled0.ipynb             py-intro
# classes-master.ipynb        scipy.ipynb
# classes.ipynb               sightings.xls
# matplotlib_instructor.ipynb small_sample.csv
# matplotlib_master.ipynb     small_sample.xls
# matplotlib_student.ipynb    testing

# %% [markdown]
# ###Excel Files
#
# Pandas can also be used to read Excel Files. This is a little different. Excel Files can hold multiple **sheets**.
#
# A DataFrame can only hold one sheet from the ExcelFile.
# So we can load the Excel File and then **parse** one sheet.

# %%
excelfile = pd.ExcelFile('sightings.xls')

# %%
# Excel files can hold multiple sheets, so we need to choose which sheet we would like to load

excelfile.sheet_names
# Out:
# [u'Sheet1']

# %%
df = excelfile.parse('Sheet1')

# %%
# This excel file has 2000 rows
## Look at the first 5 rows
print df.shape
df[:5]
# Out:
# (2000, 4)
#          Date   Time     Animal  Count
# 0  2009-04-22  19:47     Muskox      7
# 1  2009-04-22  08:41        Elk     35
# 2  2009-04-22  12:20        Owl     21
# 3  2009-04-22  14:30  Wolverine     25
# 4  2009-04-22  06:03        Fox     19
#
# [5 rows x 4 columns]

# %%
## you can also use head() to look at just the beginning of the data frame
df.head()
# Out:
#          Date   Time     Animal  Count
# 0  2009-04-22  19:47     Muskox      7
# 1  2009-04-22  08:41        Elk     35
# 2  2009-04-22  12:20        Owl     21
# 3  2009-04-22  14:30  Wolverine     25
# 4  2009-04-22  06:03        Fox     19
#
# [5 rows x 4 columns]

# %%
## find out something interesting about the data
df.describe()
# Out:
#              Count
# count  2000.000000
# mean     21.513500
# std      11.881726
# min       1.000000
# 25%      11.000000
# 50%      22.000000
# 75%      31.000000
# max      42.000000
#
# [8 rows x 1 columns]

# %%
## plot some of the data
plt.figure(figsize=(5,5))
df.boxplot();

# %% [markdown]
# ### Slicing a dataframe
# Right now I am counting all animals. What if I only care about Owls?
# This makes more sense, I can create a simple boolean mask, and create
# a new data frame of just owls.

# %%
# create a new dataframe that only contains Owl data
owl_mask = df.Animal == 'Owl'
owls = df[owl_mask]
owls.boxplot()
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x110cdd050>],
#  'caps': [<matplotlib.lines.Line2D at 0x110cdf390>,
#   <matplotlib.lines.Line2D at 0x110cdf9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x110cddcd0>,
#   <matplotlib.lines.Line2D at 0x110e056d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x110cdd690>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x110cdca10>,
#   <matplotlib.lines.Line2D at 0x110cdcc90>]}

# %%
# Use describe to learn a little about the Owl data
# eg. we have 229 samples, mincount = 1, maxcount = 42
owls.describe()
# Out:
#             Count
# count  229.000000
# mean    22.550218
# std     11.735512
# min      1.000000
# 25%     12.000000
# 50%     23.000000
# 75%     33.000000
# max     42.000000
#
# [8 rows x 1 columns]

# %% [markdown]
# ### Exercise
#
# 1. Create a wolverine mask
# 2. Do we have more Owl or Wolverine samples?
# 3. What is the difference between mean wolverine and mean owl counts

# %%
## create wolverine mask and dataset
wolverine_mask = df.Animal == 'Wolverine'
wolverines = df[wolverine_mask]

# %%
## find difference in counts and mean counts
print owls.mean()
print wolverines.mean()
# Out:
# Count     22.550218
# weight    46.000000
# dtype: float64
# Count    21.05042
# dtype: float64

# %%
owls['weight'] = 46

# %%
owls.mean()
# Out:
# Count     22.550218
# weight    46.000000
# dtype: float64

# %%
set(df.Animal)
# Out:
# {u'Elk',
#  u'Fox',
#  u'Grizzly',
#  u'Moose',
#  u'Muskox',
#  u'Owl',
#  u'Ptarmigan',
#  u'Wolf',
#  u'Wolverine'}

# %% [markdown]
# ### Groupby
#
# Instead of creating all these masks, we can also use the groupby method, and calculate the mean number of counts by animal

# %%
# use groupby
for animal, tmpdat in df.groupby('Animal'):
    print animal, tmpdat.Count.mean()
# Out:
# Elk 21.5613207547
# Fox 19.8174273859
# Grizzly 21.1422018349
# Moose 21.9777777778
# Muskox 22.5
# Owl 22.5502183406
# Ptarmigan 22.0375
# Wolf 21.0273224044
# Wolverine 21.0504201681

# %% [markdown]
# ## Iterating through rows of a Panda array
#
# Row iteration is a bit different in Pandas.  In general, it's easy to be very explicit about how you're iterating (e.g., by rows or columns).  All dataframes have an `iterrows` and `iteritems` method.  For this exercise, we'll focus on `iterrows`
#
# Iterrows - each iteration will return another row of the dataframe as (row_index, vals) pairs.

# %%
for item in df:
    print item
# Out:
# Date
# Time
# Animal
# Count

# %%
owls[:15]
# Out:
#            Date   Time Animal  Count  weight
# 2    2009-04-22  12:20    Owl     21      46
# 6    2009-04-23  03:10    Owl     23      46
# 7    2009-04-23  20:54    Owl     18      46
# 32   2009-05-04  16:21    Owl     21      46
# 34   2009-05-04  21:24    Owl     35      46
# 38   2009-05-06  05:49    Owl     38      46
# 48   2009-05-11  18:36    Owl      6      46
# 51   2009-05-11  07:12    Owl     39      46
# 53   2009-05-11  16:44    Owl     28      46
# 71   2009-05-17  07:03    Owl     27      46
# 73   2009-05-19  17:49    Owl     30      46
# 85   2009-05-25  15:33    Owl      3      46
# 112  2009-06-05  09:40    Owl     21      46
# 133  2009-06-18  18:16    Owl     35      46
# 140  2009-06-21  06:49    Owl     19      46
#
# [15 rows x 5 columns]

# %%
# Each iteration returns a Pandas Series, not a simple array.  
# This lets you do useful things with it when you become a pandas guru...
for row, item in owls.iterrows():
    print 'Row index is: ', row
    print item.Animal, item.Count
# Out:
# Row index is:  2
# Owl 21
# Row index is:  6
# Owl 23
# Row index is:  7
# Owl 18
# Row index is:  32
# Owl 21
# Row index is:  34
# Owl 35
# Row index is:  38
# Owl 38
# Row index is:  48
# Owl 6
# Row index is:  51
# Owl 39
# Row index is:  53
# Owl 28
# Row index is:  71
# Owl 27
# Row index is:  73
# Owl 30
# Row index is:  85
# Owl 3
# Row index is:  112
# Owl 21
# Row index is:  133
# Owl 35
# Row index is:  140
# Owl 19
# Row index is:  150
# Owl 14
# Row index is:  164
# Owl 5
# Row index is:  170
# Owl 17
# Row index is:  174
# Owl 40
# Row index is:  175
# Owl 33
# Row index is:  176
# Owl 9
# Row index is:  180
# Owl 26
# Row index is:  184
# Owl 25
# Row index is:  187
# Owl 40
# Row index is:  228
# Owl 12
# Row index is:  230
# Owl 30
# Row index is:  234
# Owl 39
# Row index is:  237
# Owl 40
# Row index is:  264
# Owl 37
# Row index is:  272
# Owl 41
# Row index is:  288
# Owl 32
# Row index is:  291
# Owl 24
# Row index is:  297
# Owl 29
# Row index is:  299
# Owl 16
# Row index is:  307
# Owl 5
# Row index is:  308
# Owl 37
# Row index is:  315
# Owl 19
# Row index is:  321
# Owl 27
# Row index is:  337
# Owl 21
# Row index is:  338
# Owl 6
# Row index is:  347
# Owl 7
# Row index is:  353
# Owl 19
# Row index is:  371
# Owl 28
# Row index is:  382
# Owl 11
# Row index is:  406
# Owl 39
# Row index is:  412
# Owl 6
# Row index is:  413
# Owl 22
# Row index is:  429
# Owl 21
# Row index is:  445
# Owl 14
# Row index is:  447
# Owl 16
# Row index is:  452
# Owl 42
# Row index is:  462
# Owl 36
# Row index is:  473
# Owl 11
# Row index is:  480
# Owl 36
# Row index is:  493
# Owl 1
# Row index is:  499
# Owl 7
# Row index is:  510
# Owl 20
# Row index is:  534
# Owl 39
# Row index is:  538
# Owl 7
# Row index is:  540
# Owl 9
# Row index is:  546
# Owl 22
# Row index is:  550
# Owl 31
# Row index is:  566
# Owl 30
# Row index is:  575
# Owl 34
# Row index is:  576
# Owl 1
# Row index is:  585
# Owl 10
# Row index is:  598
# Owl 31
# Row index is:  606
# Owl 5
# Row index is:  609
# Owl 21
# Row index is:  623
# Owl 8
# Row index is:  630
# Owl 29
# Row index is:  631
# Owl 19
# Row index is:  633
# Owl 33
# Row index is:  643
# Owl 20
# Row index is:  649
# Owl 2
# Row index is:  660
# Owl 36
# Row index is:  663
# Owl 37
# Row index is:  670
# Owl 35
# Row index is:  687
# Owl 7
# Row index is:  690
# Owl 34
# Row index is:  710
# Owl 17
# Row index is:  721
# Owl 28
# Row index is:  726
# Owl 27
# Row index is:  728
# Owl 23
# Row index is:  739
# Owl 9
# Row index is:  742
# Owl 16
# Row index is:  748
# Owl 8
# Row index is:  756
# Owl 34
# Row index is:  766
# Owl 38
# Row index is:  772
# Owl 29
# Row index is:  774
# Owl 21
# Row index is:  778
# Owl 20
# Row index is:  779
# Owl 31
# Row index is:  787
# Owl 35
# Row index is:  821
# Owl 24
# Row index is:  835
# Owl 30
# Row index is:  839
# Owl 38
# Row index is:  848
# Owl 23
# Row index is:  858
# Owl 25
# Row index is:  871
# Owl 23
# Row index is:  875
# Owl 33
# Row index is:  883
# Owl 25
# Row index is:  887
# Owl 27
# Row index is:  890
# Owl 24
# Row index is:  903
# Owl 38
# Row index is:  904
# Owl 37
# Row index is:  908
# Owl 14
# Row index is:  911
# Owl 7
# Row index is:  926
# Owl 29
# Row index is:  928
# Owl 8
# Row index is:  935
# Owl 27
# Row index is:  946
# Owl 39
# Row index is:  955
# Owl 2
# Row index is:  970
# Owl 36
# Row index is:  973
# Owl 13
# Row index is:  978
# Owl 35
# Row index is:  979
# Owl 2
# Row index is:  986
# Owl 19
# Row index is:  996
# Owl 4
# Row index is:  1002
# Owl 27
# Row index is:  1034
# Owl 5
# Row index is:  1037
# Owl 38
# Row index is:  1051
# Owl 32
# Row index is:  1054
# Owl 34
# Row index is:  1059
# Owl 13
# Row index is:  1065
# Owl 4
# Row index is:  1076
# Owl 11
# Row index is:  1084
# Owl 18
# Row index is:  1089
# Owl 42
# Row index is:  1097
# Owl 4
# Row index is:  1098
# Owl 29
# Row index is:  1099
# Owl 14
# Row index is:  1104
# Owl 24
# Row index is:  1113
# Owl 33
# Row index is:  1117
# Owl 10
# Row index is:  1123
# Owl 25
# Row index is:  1137
# Owl 30
# Row index is:  1142
# Owl 32
# Row index is:  1149
# Owl 20
# Row index is:  1156
# Owl 37
# Row index is:  1168
# Owl 31
# Row index is:  1170
# Owl 16
# Row index is:  1174
# Owl 13
# Row index is:  1218
# Owl 37
# Row index is:  1226
# Owl 4
# Row index is:  1239
# Owl 36
# Row index is:  1247
# Owl 4
# Row index is:  1248
# Owl 26
# Row index is:  1274
# Owl 37
# Row index is:  1277
# Owl 10
# Row index is:  1285
# Owl 28
# Row index is:  1291
# Owl 25
# Row index is:  1292
# Owl 36
# Row index is:  1319
# Owl 10
# Row index is:  1320
# Owl 39
# Row index is:  1344
# Owl 23
# Row index is:  1349
# Owl 5
# Row index is:  1404
# Owl 33
# Row index is:  1416
# Owl 40
# Row index is:  1427
# Owl 4
# Row index is:  1434
# Owl 10
# Row index is:  1472
# Owl 28
# Row index is:  1494
# Owl 8
# Row index is:  1498
# Owl 22
# Row index is:  1511
# Owl 15
# Row index is:  1516
# Owl 29
# Row index is:  1550
# Owl 24
# Row index is:  1566
# Owl 14
# Row index is:  1568
# Owl 24
# Row index is:  1569
# Owl 14
# Row index is:  1579
# Owl 11
# Row index is:  1583
# Owl 10
# Row index is:  1589
# Owl 37
# Row index is:  1590
# Owl 37
# Row index is:  1598
# Owl 21
# Row index is:  1607
# Owl 36
# Row index is:  1620
# Owl 19
# Row index is:  1622
# Owl 7
# Row index is:  1635
# Owl 24
# Row index is:  1648
# Owl 17
# Row index is:  1652
# Owl 31
# Row index is:  1666
# Owl 19
# Row index is:  1680
# Owl 12
# Row index is:  1686
# Owl 23
# Row index is:  1687
# Owl 36
# Row index is:  1693
# Owl 34
# Row index is:  1700
# Owl 23
# Row index is:  1702
# Owl 24
# Row index is:  1708
# Owl 33
# Row index is:  1711
# Owl 16
# Row index is:  1712
# Owl 6
# Row index is:  1716
# Owl 10
# Row index is:  1718
# Owl 39
# Row index is:  1735
# Owl 42
# Row index is:  1753
# Owl 8
# Row index is:  1772
# Owl 10
# Row index is:  1773
# Owl 39
# Row index is:  1780
# Owl 14
# Row index is:  1783
# Owl 41
# Row index is:  1793
# Owl 13
# Row index is:  1794
# Owl 18
# Row index is:  1797
# Owl 21
# Row index is:  1798
# Owl 40
# Row index is:  1808
# Owl 41
# Row index is:  1819
# Owl 2
# Row index is:  1823
# Owl 29
# Row index is:  1834
# Owl 5
# Row index is:  1835
# Owl 5
# Row index is:  1841
# Owl 20
# Row index is:  1849
# Owl 28
# Row index is:  1867
# Owl 38
# Row index is:  1881
# Owl 26
# Row index is:  1890
# Owl 16
# Row index is:  1891
# Owl 13
# Row index is:  1897
# Owl 25
# Row index is:  1904
# Owl 33
# Row index is:  1915
# Owl 10
# Row index is:  1928
# Owl 21
# Row index is:  1932
# Owl 12
# Row index is:  1941
# Owl 33
# Row index is:  1947
# Owl 3
# Row index is:  1949
# Owl 10
# Row index is:  1951
# Owl 12
# Row index is:  1962
# Owl 27
# Row index is:  1963
# Owl 19
# Row index is:  1970
# Owl 11
# Row index is:  1975
# Owl 41
# Row index is:  1982
# Owl 6
# Row index is:  1989
# Owl 38

# %%
df.index = df.Animal

# %%
for row, stuff in df.iterrows():
    print row
# Out:
# Muskox
# Elk
# Owl
# Wolverine
# Fox
# Elk
# Owl
# Owl
# Grizzly
# Moose
# Wolverine
# Muskox
# Moose
# Ptarmigan
# Fox
# Fox
# Moose
# Grizzly
# Elk
# Wolverine
# Muskox
# Muskox
# Wolverine
# Wolverine
# Elk
# Wolverine
# Ptarmigan
# Fox
# Wolf
# Ptarmigan
# Wolverine
# Wolverine
# Owl
# Fox
# Owl
# Wolverine
# Fox
# Moose
# Owl
# Muskox
# Wolf
# Grizzly
# Ptarmigan
# Ptarmigan
# Moose
# Grizzly
# Wolverine
# Wolverine
# Owl
# Elk
# Wolverine
# Owl
# Wolf
# Owl
# Grizzly
# Ptarmigan
# Wolf
# Grizzly
# Grizzly
# Moose
# Grizzly
# Wolverine
# Grizzly
# Muskox
# Fox
# Fox
# Wolverine
# Fox
# Fox
# Elk
# Fox
# Owl
# Grizzly
# Owl
# Fox
# Fox
# Moose
# Fox
# Wolf
# Ptarmigan
# Wolverine
# Fox
# Moose
# Elk
# Elk
# Owl
# Muskox
# Wolverine
# Wolverine
# Grizzly
# Wolverine
# Ptarmigan
# Ptarmigan
# Wolverine
# Wolverine
# Ptarmigan
# Elk
# Wolverine
# Grizzly
# Wolverine
# Moose
# Wolf
# Fox
# Fox
# Moose
# Grizzly
# Elk
# Muskox
# Ptarmigan
# Wolf
# Ptarmigan
# Owl
# Wolf
# Muskox
# Elk
# Ptarmigan
# Muskox
# Wolf
# Elk
# Fox
# Grizzly
# Ptarmigan
# Owl
# Fox
# Grizzly
# Ptarmigan
# Muskox
# Grizzly
# Wolf
# Ptarmigan
# Wolverine
# Moose
# Elk
# Grizzly
# Wolf
# Owl
# Grizzly
# Ptarmigan
# Ptarmigan
# Owl
# Moose
# Elk
# Fox
# Moose
# Fox
# Fox
# Moose
# Muskox
# Owl
# Elk
# Moose
# Muskox
# Fox
# Fox
# Owl
# Fox
# Owl
# Ptarmigan
# Owl
# Grizzly
# Moose
# Grizzly
# Moose
# Muskox
# Elk
# Wolf
# Muskox
# Ptarmigan
# Wolf
# Owl
# Owl
# Wolverine
# Wolverine
# Ptarmigan
# Elk
# Elk
# Wolverine
# Owl
# Wolf
# Moose
# Grizzly
# Moose
# Owl
# Wolf
# Elk
# Ptarmigan
# Wolverine
# Muskox
# Muskox
# Owl
# Wolverine
# Ptarmigan
# Grizzly
# Ptarmigan
# Muskox
# Moose
# Owl
# Elk
# Elk
# Ptarmigan
# Fox
# Elk
# Wolverine
# Moose
# Muskox
# Wolverine
# Muskox

# %% [markdown]
# ###Adding new Columns
#
# Pandas also makes it easy to create new columns

# %%
## add a new column based on math form original column
df['Count_2'] = df.Count * 2

# %%
df[:10]
# Out:
#                  Date   Time     Animal  Count  Count_2
# Animal
# Muskox     2009-04-22  19:47     Muskox      7       14
# Elk        2009-04-22  08:41        Elk     35       70
# Owl        2009-04-22  12:20        Owl     21       42
# Wolverine  2009-04-22  14:30  Wolverine     25       50
# Fox        2009-04-22  06:03        Fox     19       38
# Elk        2009-04-23  04:00        Elk      2        4
# Owl        2009-04-23  03:10        Owl     23       46
# Owl        2009-04-23  20:54        Owl     18       36
# Grizzly    2009-04-23  09:38    Grizzly     37       74
# Moose      2009-04-23  21:37      Moose      1        2
#
# [10 rows x 5 columns]

# %%
df['notreallymath'] = df.Count * df.Count_2 +12

# %%
df[:10]
# Out:
#                  Date   Time     Animal  Count  Count_2  notreallymath
# Animal
# Muskox     2009-04-22  19:47     Muskox      7       14            110
# Elk        2009-04-22  08:41        Elk     35       70           2462
# Owl        2009-04-22  12:20        Owl     21       42            894
# Wolverine  2009-04-22  14:30  Wolverine     25       50           1262
# Fox        2009-04-22  06:03        Fox     19       38            734
# Elk        2009-04-23  04:00        Elk      2        4             20
# Owl        2009-04-23  03:10        Owl     23       46           1070
# Owl        2009-04-23  20:54        Owl     18       36            660
# Grizzly    2009-04-23  09:38    Grizzly     37       74           2750
# Moose      2009-04-23  21:37      Moose      1        2             14
#
# [10 rows x 6 columns]

# %% [markdown]
# ## Exercise
#
# What if you want to create a new column null values?
#
# Create a new column **Gender** with no values
#
# Can you do the same thing but set everything to Female?

# %% [markdown]
# ## Afterword

# %% [markdown]
# Remember, `pandas` is an incredibly powerful tool that will take you a while to master (though it will certainly be worth it). This is just a small taste of all the things pandas can do, so don't feel discouraged if it seems totally overwhelming. Once you integrate it into your workflow, you will learn bit by bit. Also don't forget to consult the fantastic community of pythonistas around you here at Berkeley.
